# %%
text = " foreign how to calculate the total number of trailing zeros in a given factorial number of trailing zeros means number of zeros at the end so we want to find out the number of zeros at the end of a factorial when it is solved and from this topic we will get our type four of questions in the chapter number system so let us start our discussion getting a 0 at the end of X factorial depends on 5 No 5 means no zero so if we want to calculate the total number of zeros at the end of X factorial then we will be expanding the X factorial first and if in the expansion of X factorial there is a 5 then we will get a 0 at the end similarly if there are two fives then we will get two zeros at the end of the factorial and if there are no 5 in the expansion there will be no zero at the end for example let's say x factorial is 3 factorial three factorial is equal to 3 multiplied to 2 multiplied to 1 and this is equal to 6 so 3 factorial is equal to 6 and there is no zero at the end of three factorial and when you see the expansion you will find there is no 5 in the expansion and hence there is no zero at the end and with this we can conclude the number of zeros at the end of X factorial is equal to the number of fives in the X factorial and now we will solve few more examples to understand this better example one is five factorial we know 5 factorial is equal to 5 multiplied to 4 multiplied to 3 multiplied to 2 multiplied to 1. and when you solve this you will have 120 as the result and you can clearly see that we have 1 0 at the end there is one trailing zero in the result of 5 factorial and this 1 0 we are getting because we have one five present in the expansion now the question is why do we get 0 at the end whenever we have a 5 in the expansion and the answer is 5 when multiplied to an even number produces a number having zero at the end 5 here when multiplied to 2 will produce 10 and here you can see we have 0 at the end so a single five in the expansion gave us single 0 at the end now let's see the example number two we have 10 factorial and we know 10 factorial is equal to 10 multiplied to 9 multiplied to 8 multiplied to 7 multiplied to 6 multiplied to 5 multiplied to 4 multiplied to 3 multiplied to 2 and then multiplied to 1 and when you solve this you will have 3 6 2 8 8 0 0 so in this way we are getting two zeros at the end of ten factorial and the reason is presence of two fives in the expansion let us find out the two fives in this expansion the first five is clearly visible and the second five can be obtained from 10 10 is equal to 5 multiplied to two so our second five is in this ten so total two fives are there in the expansion and hence we have two zeros at the end so I hope you now understand how we are getting zeros at the end of a factorial because of presence of fives in the expansion now we can observe one issue in this method for 10 factorial we have this long expansion what if we have bigger factorial in that case this method will become 2 prone to the error hours so instead of finding the number of zeros at the end following this method we will use this formula we don't have to worry about the derivation of this formula we can directly use it to find the number of zeros at the end of X factorial these zeros at the end of X factorial will be equal to X over 5 plus X over 5 squared plus X over 5 cubed and so on and in this we will be finding the integral sum that means we are going to add the integer values from these divisions now let us solve one example problem to apply this formula in example number one we need to find the number of zeros at the end of 5 factorial we know at the end of 5 factorial we have one single 0 so let us check if this formula gives us the same answer so the number of zeros at the end of 5 factorial is equal to 5 divided by 5 plus 5 divided by 5 squared plus so on when you compare 5 factorial with X factorial you will find here in place of X we will have 5 and then we will divide 5 by 5 raised to power 1 plus 5 divided by 5 raised to power 2 plus so on I stopped at 5 divided by 5 squared because from this division we will get the integer part equal to 0 and similarly all the upcoming divisions will give the integer part equal to 0. now let us solve this 5 when divided by 5 will give us one 5 when divided by 25 will give us 0.2 and we will only note down the integer part so in this way we are getting 1 as the number of 0 at the end of 5 factorial and the same answer we got here as well so from now on we are going to use this formula to find out the number of trailing zeros or the number of zeros at the end of a given factorial let us now move on to example number two find the number of zeros at the end of 5 factorial raised to power 2 factorial so here we have something different we have 5 factorial and then the power of 5 factorial is 2 factorial we will first see the general formula to solve this kind of questions let's say 5 factorial is X factorial and 2 factorial is y factorial so X factorial raised to power y factorial we want to find out the number of zeros at the end of this the formula is number of zeros at the end of X factorial raised to power y factorial is equal to K multiplied to Y factorial we know y factorial it will be here what about k K is the number of zeros at the end of X factorial so we first need to find out the number of zeros at the end of X factorial using this formula and this will be our K and then we need to multiply y factorial with K this will give us the answer so let us now solve 5 factorial raised to power 2 factorial to find out K we first need to find out the number of zeros at the end of 5 factorial which we have found here it is equal to 1 so K will be equal to 1 and from the problem y factorial is 2 factorial and therefore the number of zeros at the end of 5 factorial raised to power 2 factorial will be K multiplied to Y factorial K is 1 and y factorial is 2 factorial which is 2 multiplied to 1 so at the end we are getting 2 as the answer and this means 5 factorial raised to power 2 factorial will have two zeros at the end of it so I hope the two example problems are clear to you and now I will provide one homework problem try to find the total number of zeros at the end of 40 factorial use the formula I have given and once you have your answer post it in comment section so this is all for this lecture see you in the next one [Music] [Applause] [Music] thank you"
# Out:
# [('foreign', 'how', 'to', 'calculate', 'the', 'total', 'number'),
#  ('how', 'to', 'calculate', 'the', 'total', 'number', 'of'),
#  ('to', 'calculate', 'the', 'total', 'number', 'of', 'trailing'),
#  ('calculate', 'the', 'total', 'number', 'of', 'trailing', 'zeros'),
#  ('the', 'total', 'number', 'of', 'trailing', 'zeros', 'in'),
#  ('total', 'number', 'of', 'trailing', 'zeros', 'in', 'a'),
#  ('number', 'of', 'trailing', 'zeros', 'in', 'a', 'given'),
#  ('of', 'trailing', 'zeros', 'in', 'a', 'given', 'factorial'),
#  ('trailing', 'zeros', 'in', 'a', 'given', 'factorial', 'number'),
#  ('zeros', 'in', 'a', 'given', 'factorial', 'number', 'of'),
#  ('in', 'a', 'given', 'factorial', 'number', 'of', 'trailing'),
#  ('a', 'given', 'factorial', 'number', 'of', 'trailing', 'zeros'),
#  ('given', 'factorial', 'number', 'of', 'trailing', 'zeros', 'means'),
#  ('factorial', 'number', 'of', 'trailing', 'zeros', 'means', 'number'),
# ...
